# %% [markdown]
# This notebook will be used to house work done for the Coursera capstone project.

# %%
import numpy as np
import pandas as pd

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
